# %% [markdown]
# <img src="./logoutn.jpg" align="right" width="150" />
#
# #### Teoría de Circuitos II
#
# # Tarea Semanal 5
#
# Farcy Facundo

# %% [markdown]
# ## ÍTEMS 1 - 4 + BONUS DESNORMALIZAR PARA D(W=0) = 200uS

# %%
from IPython.display import IFrame
IFrame("TS5.pdf", width=1000, height=1000)
# Out:
#         <iframe
#             width="1000"
#             height="1000"
#             src="TS5.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### COMPARACIÓN TRANSFERENCIA NORMALIZADA
# Según los cálculos, aplicando un bessel-thompson de grado 2 la transferencia normalizada nos quedó:
# \begin{equation}
# T(s) = \frac{3}{(s')^2+(s')^1 * 3 +3}
# \end{equation}
#
# Podemos corroborar si es correcto utilizando la función bessel de scipy.signal

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
@author: facu
"""

#-------------------------
# IMPORTACIÓN DE MÓDULOS Y CONFIGURACIONES PREVIAS
#------------------------
# Módulos externos

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt

# módulo de SciPy
from scipy import signal as sig

# Esta parte de código la agregamos SOLO en los notebooks para fijar el estilo de los gráficos.
fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 13

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

from pytc2.sistemas_lineales import analyze_sys, bodePlot, pzmap, pretty_print_bicuad_omegayq, pretty_print_SOS, plot_plantilla
from pytc2.general import print_latex, a_equal_b_latex_s

import matplotlib.patches as patches
from matplotlib.path import Path


#----------------------
# INICIO DEL CÓDIGO
#--------------------
n=2
att_min= 10
att_max=1
wp=1
ws=2.5
H_B = sig.bessel(n,wp,analog=True, output='sos',norm='delay')

pretty_print_SOS(H_B)


comment='''
_,axes_hdl_1=bodePlot(H_C, fig_id="1", filter_description="|T(S)|")
_, axes_hdl_2=bodePlot(H_C, fig_id="2", filter_description="|T(S)|")
#axes_hdl_2[0].set_xlim(left=5e3, right=2e4)
axes_hdl_2[0].set_ylim(top=1, bottom=-4);
plt.sca(axes_hdl_1[0])
plot_plantilla(filter_type="lowpass", fpass=1.0, ripple=0.5, fstop=3.0, attenuation=16)
plt.sca(axes_hdl_2[0])
plot_plantilla(filter_type="lowpass", fpass=1.0, ripple=1, fstop=3.0, attenuation=16)
'''
# Out:
# $\displaystyle   \frac{  3 }{s^2 + s \,\,   3 +   3 }$

# %% [markdown]
# Habiendo comprobado que el desarrollo de bessel fue correcto, armamos la función transferencia obtenida a partir del circuito Sallen-key, con los valores de componentes normalizados. Deberíamos obtener la misma transferencia.

# %%
G1=G2=2.
C1=1.
C2=4/3

w0 = np.sqrt(G1*G2/(C1*C2))
q= w0*C2/(G1+G2)

num = np.array([w0**2])
den = np.array([1., w0/q,w0**2])
T = sig.TransferFunction(num,den)

pretty_print_SOS(num,den)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 12
#       9 den = np.array([1., w0/q,w0**2])
#      10 T = sig.TransferFunction(num,den)
# ---> 12 pretty_print_SOS(num,den)
#
# File ~/.local/lib/python3.8/site-packages/pytc2/sistemas_lineales.py:1048, in pretty_print_SOS(mySOS, mode, displaystr)
#    1045 if not isinstance(mySOS, np.ndarray):
#    1046     raise ValueError('mySOS debe ser una matriz numpy')
# -> 1048 if mySOS.shape[1] != 6:
#    1049     raise ValueError('mySOS debe tener exactamente 6 columnas')
#    1051 if not isinstance(displaystr, bool):
#
# IndexError: tuple index out of range

# %% [markdown]
# Nuevamente, si se reordenaran los valores del numeradorobtendríamos los correspondientes al hallado en el pdf.
# Procedemos graficando para corroborar si se cumple lo deseado.

# %%
wc=2*np.pi*1.5e3
ws=2*np.pi*4.5e3
_,axes_hdl_1=bodePlot(H_C, fig_id="1", filter_description="|T(S)|")

_, axes_hdl_2=bodePlot(H_C, fig_id="2", filter_description="|T(S)|")

H_C_pzmap = sig.TransferFunction(H_C_ba[0], H_C_ba[1])
_,_,=pzmap(H_C_pzmap, fig_id="3")

#addCuadrado(axes_hdl_1[0],att_max=0.5, att_min=16,wc=wc,ws=ws,wi=1e3, wf=1e5)
#addCuadrado(axes_hdl_2[0],att_max=0.5, att_min=16,wc=wc,ws=ws,wi=1e3,wf=1e5)
axes_hdl_2[0].set_xlim(left=5e3, right=2e4)
axes_hdl_2[0].set_ylim(top=1, bottom=-4);

# %% [markdown]
# ## FUNCIÓN TRASNFERENCIA CON VALORES
# Con los valores de los componentes y las funciones transferencias de los circuitos propuestos, verificamos si se cumple lo deseado

# %%
#------ VALORES
R1=R3=R4=18e3
R2=R5=33e3
C1=C2=5.6e-9

G1=1/R1
G2=1/R2
G3=1/R3
G4=1/R4
G5=1/R5


num_H1= G1/G3*np.array([0., 0., (G3/C1)**2])
den_H1= np.array([1.,G2/C1,(G3/C1)**2])
num_H2= np.array([0., 0., G5/C2])
den_H2= np.array([0., 1., G5/C2])


num_H = np.polymul(num_H1, num_H2)
den_H = np.polymul(den_H1, den_H2)

H1 = sig.TransferFunction(num_H1, den_H1)
H2 = sig.TransferFunction(num_H2, den_H2)
H = sig.TransferFunction(num_H, den_H)

_, axes_hdl_4=bodePlot(H1, fig_id="4", filter_description="|T1(S)|")
_,_,=bodePlot(H2, fig_id="4", filter_description="|T2(S)|")
_,_,=bodePlot(H, fig_id="4", filter_description="|T(S)|")

H_line = axes_hdl_4[0].get_lines()
H_line[0].set_linestyle('-.')
H_line[1].set_linestyle('--')
# Out:
# /home/facu/.local/lib/python3.8/site-packages/scipy/signal/_filter_design.py:1746: BadCoefficients: Badly conditioned filter coefficients (numerator): the results may be meaningless
#   warnings.warn("Badly conditioned filter coefficients (numerator): the "

# %% [markdown]
# ## SIMULACION

# %% [markdown]
# En SPICE obtuvimos lo siguiente

# %% [markdown]
# <img src="Spice1.png" display="block" margin=auto width=900>
# <img src="Spice2.png" display="block" margin=auto width=900>
# <img src="Spice4.png" display="block" margin=auto width=900>
